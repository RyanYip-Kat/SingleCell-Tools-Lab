# %%
from pyscenic.utils import load_motifs
import operator as op
from IPython.display import HTML, display
import pandas as pd
import scanpy as sc
import loompy as lp

BASE_URL = "http://motifcollections.aertslab.org/v9/logos/"
COLUMN_NAME_LOGO = "MotifLogo"
COLUMN_NAME_MOTIF_ID = "MotifID"
# helper functions (not yet integrated into pySCENIC):

COLUMN_NAME_TARGETS = "TargetGenes"

# %%
def display_logos(df: pd.DataFrame, top_target_genes: int = 3, base_url: str = BASE_URL):
    """
    :param df:
    :param base_url:
    """
    # Make sure the original dataframe is not altered.
    df = df.copy()
    
    # Add column with URLs to sequence logo.
    def create_url(motif_id):
        return '<img src="{}{}.png" style="max-height:124px;"></img>'.format(base_url, motif_id)
    df[("Enrichment", COLUMN_NAME_LOGO)] = list(map(create_url, df.index.get_level_values(COLUMN_NAME_MOTIF_ID)))
    
    # Truncate TargetGenes.
    def truncate(col_val):
        return sorted(col_val, key=op.itemgetter(1))[:top_target_genes]
    df[("Enrichment", COLUMN_NAME_TARGETS)] = list(map(truncate, df[("Enrichment", COLUMN_NAME_TARGETS)]))
    
    MAX_COL_WIDTH = pd.get_option('display.max_colwidth')
    pd.set_option('display.max_colwidth', 200)
    display(HTML(df.head().to_html(escape=False)))
    pd.set_option('display.max_colwidth', MAX_COL_WIDTH)

# %%
df_motifs = load_motifs('loom/aging-11/BC/reg.csv')

# %%
selected_motifs = ['PAX5','TCF3','EBF1']
df_motifs_sel = df_motifs.iloc[ [ True if x in selected_motifs else False for x in df_motifs.index.get_level_values('TF') ] ,:]

# %%
df_motifs_sel
# Out:
#                                         Enrichment  \
#                                                AUC
# TF   MotifID
# PAX5 cisbp__M4475                         0.106258
#      cisbp__M4489                         0.111169
#      dbcorrdb__IKZF1__ENCSR000EUJ_1__m1   0.092705
#      homer__AAAGRGGAAGTG_SpiB             0.091839
#      dbcorrdb__SPI1__ENCSR000BGW_1__m1    0.089499
# ...                                            ...
#      dbcorrdb__SPI1__ENCSR000BGQ_1__m1    0.088096
#      hocomoco__IRF8_HUMAN.H11MO.0.B       0.097240
#      dbcorrdb__SPI1__ENCSR000BIJ_1__m1    0.091386
#      dbcorrdb__EP300__ENCSR000DZG_1__m1   0.081365
#      hocomoco__IRF4_HUMAN.H11MO.0.A       0.096970
#
#                                                                                             \
#                                                                                 Annotation
# TF   MotifID
# PAX5 cisbp__M4475                        gene is annotated for similar motif dbcorrdb__...
#      cisbp__M4489                        gene is annotated for similar motif dbcorrdb__...
#      dbcorrdb__IKZF1__ENCSR000EUJ_1__m1  motif similar to dbcorrdb__PAX5__ENCSR000BHJ_1...
#      homer__AAAGRGGAAGTG_SpiB            gene is annotated for similar motif dbcorrdb__...
#      dbcorrdb__SPI1__ENCSR000BGW_1__m1   gene is annotated for similar motif dbcorrdb__...
# ...                                                                                    ...
#      dbcorrdb__SPI1__ENCSR000BGQ_1__m1   motif similar to dbcorrdb__PAX5__ENCSR000BHJ_1...
#      hocomoco__IRF8_HUMAN.H11MO.0.B      gene is annotated for similar motif dbcorrdb__...
#      dbcorrdb__SPI1__ENCSR000BIJ_1__m1   gene is annotated for similar motif dbcorrdb__...
#      dbcorrdb__EP300__ENCSR000DZG_1__m1  motif similar to dbcorrdb__PAX5__ENCSR000BHJ_1...
#      hocomoco__IRF4_HUMAN.H11MO.0.A      gene is annotated for similar motif dbcorrdb__...
#
#                                                                                             \
#                                                                                    Context
# TF   MotifID
# PAX5 cisbp__M4475                        (weight>75.0%, hg38__refseq-r80__10kb_up_and_d...
#      cisbp__M4489                        (weight>75.0%, hg38__refseq-r80__10kb_up_and_d...
#      dbcorrdb__IKZF1__ENCSR000EUJ_1__m1  (weight>75.0%, hg38__refseq-r80__10kb_up_and_d...
#      homer__AAAGRGGAAGTG_SpiB            (weight>75.0%, hg38__refseq-r80__10kb_up_and_d...
#      dbcorrdb__SPI1__ENCSR000BGW_1__m1   (weight>75.0%, hg38__refseq-r80__10kb_up_and_d...
# ...                                                                                    ...
#      dbcorrdb__SPI1__ENCSR000BGQ_1__m1   (hg38__refseq-r80__10kb_up_and_down_tss.mc9nr,...
#      hocomoco__IRF8_HUMAN.H11MO.0.B      (hg38__refseq-r80__10kb_up_and_down_tss.mc9nr,...
#      dbcorrdb__SPI1__ENCSR000BIJ_1__m1   (hg38__refseq-r80__10kb_up_and_down_tss.mc9nr,...
#      dbcorrdb__EP300__ENCSR000DZG_1__m1  (hg38__refseq-r80__10kb_up_and_down_tss.mc9nr,...
#      hocomoco__IRF4_HUMAN.H11MO.0.A      (hg38__refseq-r80__10kb_up_and_down_tss.mc9nr,...
#
#                                                                          \
#                                         MotifSimilarityQvalue       NES
# TF   MotifID
# PAX5 cisbp__M4475                                    0.000003  4.825522
#      cisbp__M4489                                    0.000002  5.189401
#      dbcorrdb__IKZF1__ENCSR000EUJ_1__m1              0.000000  3.821436
#      homer__AAAGRGGAAGTG_SpiB                        0.000071  3.757266
#      dbcorrdb__SPI1__ENCSR000BGW_1__m1               0.000405  3.583907
# ...                                                       ...       ...
#      dbcorrdb__SPI1__ENCSR000BGQ_1__m1               0.000012  3.914346
#      hocomoco__IRF8_HUMAN.H11MO.0.B                  0.000003  4.657880
#      dbcorrdb__SPI1__ENCSR000BIJ_1__m1               0.000008  4.181842
#      dbcorrdb__EP300__ENCSR000DZG_1__m1              0.000000  3.367034
#      hocomoco__IRF4_HUMAN.H11MO.0.A                  0.000000  4.635882
#
#                                                                        \
#                                         OrthologousIdentity RankAtMax
# TF   MotifID
# PAX5 cisbp__M4475                                       1.0       540
#      cisbp__M4489                                       1.0      2681
#      dbcorrdb__IKZF1__ENCSR000EUJ_1__m1                 1.0      1568
#      homer__AAAGRGGAAGTG_SpiB                           1.0      1155
#      dbcorrdb__SPI1__ENCSR000BGW_1__m1                  1.0      2033
# ...                                                     ...       ...
#      dbcorrdb__SPI1__ENCSR000BGQ_1__m1                  1.0      1560
#      hocomoco__IRF8_HUMAN.H11MO.0.B                     1.0       710
#      dbcorrdb__SPI1__ENCSR000BIJ_1__m1                  1.0      2331
#      dbcorrdb__EP300__ENCSR000DZG_1__m1                 1.0      2134
#      hocomoco__IRF4_HUMAN.H11MO.0.A                     1.0       453
#
#
#                                                                                TargetGenes
# TF   MotifID
# PAX5 cisbp__M4475                        [(GPR18, 1.6735250260866281), (SMIM14, 0.88342...
#      cisbp__M4489                        [(GPR18, 1.6735250260866281), (SMIM14, 0.88342...
#      dbcorrdb__IKZF1__ENCSR000EUJ_1__m1  [(GPR18, 1.6735250260866281), (LIMD2, 0.883426...
#      homer__AAAGRGGAAGTG_SpiB            [(LYN, 1.6735250260866281), (SYK, 0.8834268482...
#      dbcorrdb__SPI1__ENCSR000BGW_1__m1   [(LIMD2, 1.6735250260866281), (MTPN, 0.8834268...
# ...                                                                                    ...
#      dbcorrdb__SPI1__ENCSR000BGQ_1__m1   [(ALOX5AP, 1.6735250260866281), (GPR18, 0.8834...
#      hocomoco__IRF8_HUMAN.H11MO.0.B      [(ZEB2, 1.6735250260866281), (GPR18, 0.8834268...
#      dbcorrdb__SPI1__ENCSR000BIJ_1__m1   [(ALOX5AP, 1.6735250260866281), (GPR18, 0.8834...
#      dbcorrdb__EP300__ENCSR000DZG_1__m1  [(GPR18, 1.6735250260866281), (ZEB2, 0.8834268...
#      hocomoco__IRF4_HUMAN.H11MO.0.A      [(GPR18, 1.6735250260866281), (ZEB2, 0.8834268...
#
# [65 rows x 8 columns]

# %%
#display_logos(df_motifs.head())
display_logos( df_motifs_sel.sort_values([('Enrichment','NES')], ascending=False).head(9))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th colspan="9" halign="left">Enrichment</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>AUC</th>
#       <th>Annotation</th>
#       <th>Context</th>
#       <th>MotifSimilarityQvalue</th>
#       <th>NES</th>
#       <th>OrthologousIdentity</th>
#       <th>RankAtMax</th>
#       <th>TargetGenes</th>
#       <th>MotifLogo</th>
#     </tr>
#     <tr>
#       <th>TF</th>
#       <th>MotifID</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="5" valign="top">PAX5</th>
#       <th>cisbp__M4489</th>
#       <td>0.106027</td>
#       <td>gene is annotated for similar motif dbcorrdb__PAX5__ENCSR000BHJ_1__m2 ('PAX5 (ENCSR000BHJ-1, motif 2)'; q-value = 1.72e-06)</td>
#       <td>(hg38__refseq-r80__10kb_up_and_down_tss.mc9nr, activating, top50perTarget)</td>
#       <td>0.000002</td>
#       <td>5.372377</td>
#       <td>1.0</td>
#       <td>1425</td>
#       <td>[(PLAC8, 0.0011768970297239732), (LAPTM5, 0.1250222349227719), (CXCR4, 0.1513492750572744)]</td>
#       <td><img src="http://motifcollections.aertslab.org/v9/logos/cisbp__M4489.png" style="max-height:124px;"></img></td>
#     </tr>
#     <tr>
#       <th>cisbp__M4489</th>
#       <td>0.111169</td>
#       <td>gene is annotated for similar motif dbcorrdb__PAX5__ENCSR000BHJ_1__m2 ('PAX5 (ENCSR000BHJ-1, motif 2)'; q-value = 1.72e-06)</td>
#       <td>(weight>75.0%, hg38__refseq-r80__10kb_up_and_down_tss.mc9nr, activating)</td>
#       <td>0.000002</td>
#       <td>5.189401</td>
#       <td>1.0</td>
#       <td>2681</td>
#       <td>[(MEF2C, 0.43093183532262497), (COL19A1, 0.4340176830003246), (BAZ2A, 0.4493684229996896)]</td>
#       <td><img src="http://motifcollections.aertslab.org/v9/logos/cisbp__M4489.png" style="max-height:124px;"></img></td>
#     </tr>
#     <tr>
#       <th>homer__AAAGRGGAAGTG_SpiB</th>
#       <td>0.103005</td>
#       <td>gene is annotated for similar motif dbcorrdb__PAX5__ENCSR000BHJ_1__m2 ('PAX5 (ENCSR000BHJ-1, motif 2)'; q-value = 7.11e-05)</td>
#       <td>(hg38__refseq-r80__10kb_up_and_down_tss.mc9nr, activating, top50perTarget)</td>
#       <td>0.000071</td>
#       <td>5.126659</td>
#       <td>1.0</td>
#       <td>1241</td>
#       <td>[(TAGAP, 0.0011768970297239732), (MANBA, 0.1250222349227719), (ALOX5AP, 0.1513492750572744)]</td>
#       <td><img src="http://motifcollections.aertslab.org/v9/logos/homer__AAAGRGGAAGTG_SpiB.png" style="max-height:124px;"></img></td>
#     </tr>
#     <tr>
#       <th>dbcorrdb__PAX5__ENCSR000BJI_1__m1</th>
#       <td>0.186335</td>
#       <td>gene is directly annotated</td>
#       <td>(hg38__refseq-r80__10kb_up_and_down_tss.mc9nr, top5perTarget, activating)</td>
#       <td>0.000000</td>
#       <td>5.061688</td>
#       <td>1.0</td>
#       <td>1157</td>
#       <td>[(SMIM14, 0.08699154186886034), (LYST, 0.19399471310044436), (MCTP2, 0.5451611881504062)]</td>
#       <td><img src="http://motifcollections.aertslab.org/v9/logos/dbcorrdb__PAX5__ENCSR000BJI_1__m1.png" style="max-height:124px;"></img></td>
#     </tr>
#     <tr>
#       <th>factorbook__PU1</th>
#       <td>0.101168</td>
#       <td>gene is annotated for similar motif dbcorrdb__PAX5__ENCSR000BHJ_1__m2 ('PAX5 (ENCSR000BHJ-1, motif 2)'; q-value = 6.12e-08)</td>
#       <td>(hg38__refseq-r80__10kb_up_and_down_tss.mc9nr, activating, top50perTarget)</td>
#       <td>0.000000</td>
#       <td>4.977292</td>
#       <td>1.0</td>
#       <td>1247</td>
#       <td>[(APLP2, 0.0011768970297239732), (POLD4, 0.1250222349227719), (HLA-DMB, 0.1513492750572744)]</td>
#       <td><img src="http://motifcollections.aertslab.org/v9/logos/factorbook__PU1.png" style="max-height:124px;"></img></td>
#     </tr>
#   </tbody>
# </table>
